# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/U.S._Chronic_Disease_Indicators__CDI_.csv")
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
# ...

# %% [markdown]
# # Proportion of missing values

# %%
df.isnull().mean()
# Out:
# YearStart                    0.000000
# YearEnd                      0.000000
# LocationAbbr                 0.000000
# LocationDesc                 0.000000
# DataSource                   0.000000
# Topic                        0.000000
# Question                     0.000000
# Response                     0.847633
# DataValueUnit                0.084030
# DataValueType                0.000000
# DataValue                    0.279294
# DataValueAlt                 0.325913
# DataValueFootnoteSymbol      0.562613
# DatavalueFootnote            0.562932
# LowConfidenceLimit           0.401479
# HighConfidenceLimit          0.401479
# StratificationCategory1      0.000000
# Stratification1              0.000000
# StratificationCategory2      0.847633
# Stratification2              0.847633
# StratificationCategory3      0.847633
# Stratification3              0.847633
# GeoLocation                  0.006933
# ResponseID                   0.847656
# LocationID                   0.000000
# ...

# %%
df["Topic"].value_counts()
# Out:
# Diabetes                                           79631
# Chronic Obstructive Pulmonary Disease              78729
# Cardiovascular Disease                             75787
# Arthritis                                          41765
# Overarching Conditions                             39362
# Asthma                                             39261
# Nutrition, Physical Activity, and Weight Status    33621
# Alcohol                                            31850
# Tobacco                                            29306
# Older Adults                                       15300
# Cancer                                             14101
# Chronic Kidney Disease                             12395
# Oral Health                                        11137
# Mental Health                                       7225
# Immunization                                        5220
# Disability                                          2968
# ...

# %%
df["Question"].nunique()
# Out:
# 203

# %%
df[~df["Response"].isnull()]
# Out:
#         YearStart  YearEnd LocationAbbr   LocationDesc            DataSource  \
# 261          2013     2013           OK       Oklahoma                  NVSS
# 263          2014     2014           CO       Colorado                  NVSS
# 267          2012     2012           NH  New Hampshire                  NVSS
# 268          2013     2013           VT        Vermont  State Inpatient Data
# 271          2011     2011           AZ        Arizona                  NVSS
# ...           ...      ...          ...            ...                   ...
# 519685       2011     2011           SD   South Dakota                  NVSS
# 519693       2010     2010           NV         Nevada             SEDD; SID
# 519696       2013     2013           VT        Vermont  State Inpatient Data
# 519705       2013     2013           TX          Texas  State Inpatient Data
# 519706       2011     2011           SD   South Dakota                  NVSS
#
# ...

# %%
df.shape
# Out:
# (519718, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519718 entries, 0 to 519717
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  519718 non-null  int64
#  1   YearEnd                    519718 non-null  int64
#  2   LocationAbbr               519718 non-null  object
#  3   LocationDesc               519718 non-null  object
#  4   DataSource                 519718 non-null  object
#  5   Topic                      519718 non-null  object
#  6   Question                   519718 non-null  object
#  7   Response                   79188 non-null   object
#  8   DataValueUnit              476046 non-null  object
#  9   DataValueType              519718 non-null  object
#  10  DataValue                  374564 non-null  object
#  11  DataValueAlt               350335 non-null  float64
#  12  DataValueFootnoteSymbol    227318 non-null  object
# ...

# %%
df["Question"].apply(len).max()
# Out:
# 179

# %%
df[df["LocationAbbr"] == ""]["GeoLocation"].unique()
# Out:
# array([], dtype=object)

# %%
df["Question"].unique()
# Out:
# array(['Amount of alcohol excise tax by beverage type (wine)',
#        'Amount of alcohol excise tax by beverage type (beer)',
#        'Amount of alcohol excise tax by beverage type (distilled spirits)',
#        'Obesity among adults aged >= 18 years',
#        'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years',
#        'Binge drinking frequency among adults aged >= 18 years who binge drink',
#        'Arthritis among adults aged >= 18 years who have diabetes',
#        'Foot examination among adults aged >= 18 years with diagnosed diabetes',
#        'Current smoking among adults aged >= 18 years',
#        'Chronic liver disease mortality', 'Mortality from heart failure',
#        'Heavy drinking among adults aged >= 18 years',
#        'Quit attempts in the past year among current smokers',
#        'Prevalence of sufficient sleep among adults aged >= 18 years',
#        'Hospitalization for acute myocardial infarction', 'Poverty',
# ...

# %%
df[~df.duplicated("Question", keep="first")]["Topic"].value_counts()
# Out:
# Nutrition, Physical Activity, and Weight Status    37
# Cancer                                             20
# Diabetes                                           20
# Cardiovascular Disease                             18
# Chronic Obstructive Pulmonary Disease              16
# Overarching Conditions                             16
# Tobacco                                            16
# Alcohol                                            16
# Arthritis                                          10
# Oral Health                                         9
# Asthma                                              9
# Chronic Kidney Disease                              4
# Older Adults                                        4
# Mental Health                                       3
# Reproductive Health                                 3
# Disability                                          1
# Immunization                                        1
# Name: Topic, dtype: int64

# %%
for q in df["Question"].unique():
    topics = df[df["Question"] == q]["Topic"].value_counts()
    print(topics)
# Out:
# Alcohol    110
# Name: Topic, dtype: int64
# Alcohol    110
# Name: Topic, dtype: int64
# Alcohol    110
# Name: Topic, dtype: int64
# Nutrition, Physical Activity, and Weight Status    5220
# Name: Topic, dtype: int64
# Cardiovascular Disease    7488
# Name: Topic, dtype: int64
# Alcohol    5220
# Name: Topic, dtype: int64
# Arthritis    5220
# Name: Topic, dtype: int64
# Diabetes    5220
# Name: Topic, dtype: int64
# Tobacco    5220
# Name: Topic, dtype: int64
# Alcohol    6135
# Name: Topic, dtype: int64
# Cardiovascular Disease    6135
# Name: Topic, dtype: int64
# Alcohol    5220
# Name: Topic, dtype: int64
# Tobacco    5220
# Name: Topic, dtype: int64
# Overarching Conditions    3480
# Name: Topic, dtype: int64
# Cardiovascular Disease    2637
# Name: Topic, dtype: int64
# Overarching Conditions    2968
# Name: Topic, dtype: int64
# Chronic Obstructive Pulmonary Disease    5220
# Name: Topic, dtype: int64
# Cancer    3250
# Name: Topic, dtype: int64
# ...

# %%
df.shape
# Out:
# (519718, 34)

# %%
df[df["Topic"] == "Diabetes"].shape
# Out:
# (79631, 34)

# %%
df.iloc[0]
# Out:
# YearStart                                                                 2015
# YearEnd                                                                   2015
# LocationAbbr                                                                US
# LocationDesc                                                     United States
# DataSource                                                                APIS
# Topic                                                                  Alcohol
# Question                     Amount of alcohol excise tax by beverage type ...
# Response                                                                   NaN
# DataValueUnit                                                                $
# DataValueType                                                       US Dollars
# DataValue                                                                  NaN
# DataValueAlt                                                               NaN
# ...

# %%
df["Question"].unique()
# Out:
# array(['Amount of alcohol excise tax by beverage type (wine)',
#        'Amount of alcohol excise tax by beverage type (beer)',
#        'Amount of alcohol excise tax by beverage type (distilled spirits)',
#        'Obesity among adults aged >= 18 years',
#        'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years',
#        'Binge drinking frequency among adults aged >= 18 years who binge drink',
#        'Arthritis among adults aged >= 18 years who have diabetes',
#        'Foot examination among adults aged >= 18 years with diagnosed diabetes',
#        'Current smoking among adults aged >= 18 years',
#        'Chronic liver disease mortality', 'Mortality from heart failure',
#        'Heavy drinking among adults aged >= 18 years',
#        'Quit attempts in the past year among current smokers',
#        'Prevalence of sufficient sleep among adults aged >= 18 years',
#        'Hospitalization for acute myocardial infarction', 'Poverty',
# ...

# %%
df[df["Topic"] == "Tobacco"]["LocationDesc"].value_counts()
# Out:
# Vermont                 539
# New Jersey              539
# New York                539
# Montana                 539
# Guam                    539
# Alabama                 539
# Maine                   539
# Washington              539
# Tennessee               539
# California              539
# Georgia                 539
# Wyoming                 539
# Colorado                539
# Alaska                  539
# North Carolina          539
# Texas                   539
# Hawaii                  539
# North Dakota            539
# Pennsylvania            539
# Florida                 539
# Connecticut             539
# Arizona                 539
# District of Columbia    539
# Rhode Island            539
# Wisconsin               539
# Oregon                  539
# Kansas                  539
# Missouri                539
# South Dakota            539
# Maryland                539
# West Virginia           539
# South Carolina          539
# Idaho                   539
# ...

# %%
df[df["Topic"] == 'Tobacco']["Question"].unique()
# Out:
# array(['Current smoking among adults aged >= 18 years',
#        'Quit attempts in the past year among current smokers',
#        'Current smokeless tobacco use among adults aged >= 18 years',
#        'Amount of tobacco product excise tax',
#        'States that allow stronger local tobacco control and prevention laws',
#        'Sale of cigarette packs',
#        'Current smokeless tobacco use among youth',
#        'Cigarette smoking before pregnancy',
#        'Current cigarette smoking among women aged 18-44 years',
#        'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years who smoke',
#        'Current cigarette smoking among youth',
#        'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years who smoke',
#        'Percent tobacco revenue to fund at CDC recommended level',
# ...

# %%
df["Topic"].unique()
# Out:
# array(['Alcohol', 'Nutrition, Physical Activity, and Weight Status',
#        'Cardiovascular Disease', 'Arthritis', 'Diabetes', 'Tobacco',
#        'Overarching Conditions', 'Chronic Obstructive Pulmonary Disease',
#        'Cancer', 'Chronic Kidney Disease', 'Asthma', 'Disability',
#        'Oral Health', 'Older Adults', 'Mental Health', 'Immunization',
#        'Reproductive Health'], dtype=object)

# %%
question1 = 'Current smokeless tobacco use among youth'
question2 = 'Secondary schools that have a comprehensive tobacco-free school policy in place'
question3 = "States with strong polices that require retail licenses to sell tobacco products"
question4 = 'Current cigarette smoking among youth'
question5 = 'States that allow stronger local tobacco control and prevention laws'

# %%
df[df["Question"] == question1]["YearStart"].value_counts()
# Out:
# 2015    55
# 2013    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question1]["StratificationCategory1"].value_counts()
# Out:
# Overall    110
# Name: StratificationCategory1, dtype: int64

# %%
df[df["Question"] == question2]["YearStart"].value_counts()
# Out:
# 2016    55
# 2014    55
# 2012    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question3]["YearStart"].value_counts()
# Out:
# 2015    54
# 2014    54
# 2013    54
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question4]["YearStart"].value_counts()
# Out:
# 2015    55
# 2013    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question5]["YearStart"].value_counts()
# Out:
# 2015    54
# 2014    54
# 2013    54
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question4]["StratificationCategory1"].value_counts()
# Out:
# Overall    110
# Name: StratificationCategory1, dtype: int64

# %%
df[(df["Question"] == question1)].shape
# Out:
# (110, 34)

# %%
df[df["Question"] == question3].shape
# Out:
# (162, 34)

# %%
df[df["Question"] == question1]["LocationDesc"].value_counts().sort_index()
# Out:
# Alabama                 2
# Alaska                  2
# Arizona                 2
# Arkansas                2
# California              2
# Colorado                2
# Connecticut             2
# Delaware                2
# District of Columbia    2
# Florida                 2
# Georgia                 2
# Guam                    2
# Hawaii                  2
# Idaho                   2
# Illinois                2
# Indiana                 2
# Iowa                    2
# Kansas                  2
# Kentucky                2
# Louisiana               2
# Maine                   2
# Maryland                2
# Massachusetts           2
# Michigan                2
# Minnesota               2
# Mississippi             2
# Missouri                2
# Montana                 2
# Nebraska                2
# Nevada                  2
# New Hampshire           2
# New Jersey              2
# New Mexico              2
# New York                2
# North Carolina          2
# ...

# %%
df[df["Question"] == question3]["LocationDesc"].value_counts().sort_index()
# Out:
# Alabama                 3
# Alaska                  3
# Arizona                 3
# Arkansas                3
# California              3
# Colorado                3
# Connecticut             3
# Delaware                3
# District of Columbia    3
# Florida                 3
# Georgia                 3
# Guam                    3
# Hawaii                  3
# Idaho                   3
# Illinois                3
# Indiana                 3
# Iowa                    3
# Kansas                  3
# Kentucky                3
# Louisiana               3
# Maine                   3
# Maryland                3
# Massachusetts           3
# Michigan                3
# Minnesota               3
# Mississippi             3
# Missouri                3
# Montana                 3
# Nebraska                3
# Nevada                  3
# New Hampshire           3
# New Jersey              3
# New Mexico              3
# New York                3
# North Carolina          3
# ...

# %%
question1 = 'Obesity among high school students'
question2 = 'Secondary schools that offer less healthy foods as competitive foods'
question3 = 'Participation in daily school physical education classes among high school students'
question4 = 'Secondary schools that allow students to purchase soda or fruit drinks'
question5 = 'Secondary schools that allow community-sponsored use of physical activity facilities by youth outside of normal school hours'

# %%
df[df["Question"] == question1]["YearStart"].value_counts()
# Out:
# 2015    55
# 2013    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question2]["YearStart"].value_counts()
# Out:
# 2016    55
# 2014    55
# 2012    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question3]["YearStart"].value_counts()
# Out:
# 2015    55
# 2013    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question4]["YearStart"].value_counts()
# Out:
# 2016    55
# 2014    55
# 2012    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question5]["YearStart"].value_counts()
# Out:
# 2016    55
# 2014    55
# 2012    55
# Name: YearStart, dtype: int64

# %%
df[df["Question"] == question4]["DataValue"]
# Out:
# 4283      15.2
# 6256      21.3
# 11018     43.8
# 11449     11.8
# 12041     25.3
#           ...
# 501390    21.4
# 505857    20.4
# 514272      44
# 514614    22.7
# 519517    30.1
# Name: DataValue, Length: 165, dtype: object

# %%
df[df["Question"] == question3]["DataValue"]
# Out:
# 1209       NaN
# 1578       NaN
# 5895       NaN
# 10528     38.3
# 17450     35.7
#           ...
# 499504    30.9
# 503644    11.1
# 506855    22.3
# 514010    32.8
# 518423     NaN
# Name: DataValue, Length: 110, dtype: object

# %%
df.iloc[321]
# Out:
# YearStart                                                             2012
# YearEnd                                                               2012
# LocationAbbr                                                            GU
# LocationDesc                                                          Guam
# DataSource                                                           BRFSS
# Topic                                                              Tobacco
# Question                     Current smoking among adults aged >= 18 years
# Response                                                               NaN
# DataValueUnit                                                            %
# DataValueType                                      Age-adjusted Prevalence
# DataValue                                                             29.8
# DataValueAlt                                                          29.8
# ...
