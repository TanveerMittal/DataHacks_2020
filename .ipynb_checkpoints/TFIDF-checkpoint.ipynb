# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import re
from utils import *
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.metrics import homogeneity_score
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/U.S._Chronic_Disease_Indicators__CDI_.csv")
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2015     2015           US         United States       APIS  Alcohol
# 1       2012     2012           DC  District of Columbia       APIS  Alcohol
# 2       2012     2012           GU                  Guam       APIS  Alcohol
# 3       2012     2012           PR           Puerto Rico       APIS  Alcohol
# 4       2012     2012           US         United States       APIS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Amount of alcohol excise tax by beverage type ...      NaN             $
# 1  Amount of alcohol excise tax by beverage type ...      NaN             $
# 2  Amount of alcohol excise tax by beverage type ...      NaN             $
# 3  Amount of alcohol excise tax by beverage type ...      NaN             $
# 4  Amount of alcohol excise tax by beverage type ...      NaN             $
#
#   DataValueType  ... LocationID  TopicID QuestionID DataValueTypeID  \
# 0    US Dollars  ...         59      ALC   ALC8_0_2             USD
# 1    US Dollars  ...         11      ALC   ALC8_0_1             USD
# 2    US Dollars  ...         66      ALC   ALC8_0_1             USD
# 3    US Dollars  ...         72      ALC   ALC8_0_1             USD
# 4    US Dollars  ...         59      ALC   ALC8_0_1             USD
#
#    StratificationCategoryID1  StratificationID1 StratificationCategoryID2  \
# 0                    OVERALL                OVR                       NaN
# 1                    OVERALL                OVR                       NaN
# 2                    OVERALL                OVR                       NaN
# 3                    OVERALL                OVR                       NaN
# 4                    OVERALL                OVR                       NaN
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0               NaN                       NaN               NaN
# 1               NaN                       NaN               NaN
# 2               NaN                       NaN               NaN
# 3               NaN                       NaN               NaN
# 4               NaN                       NaN               NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# # Keep only the unique questions

# %%
df = df[~df.duplicated("Question", keep="first")][["Topic", "Question"]].reset_index(drop=True)
df.head()
# Out:
#                                              Topic  \
# 0                                          Alcohol
# 1                                          Alcohol
# 2                                          Alcohol
# 3  Nutrition, Physical Activity, and Weight Status
# 4                           Cardiovascular Disease
#
#                                             Question
# 0  Amount of alcohol excise tax by beverage type ...
# 1  Amount of alcohol excise tax by beverage type ...
# 2  Amount of alcohol excise tax by beverage type ...
# 3              Obesity among adults aged >= 18 years
# 4  Hospitalization for heart failure among Medica...

# %% [markdown]
# # Breakdown of questions' topics

# %%
topics = df["Topic"].value_counts()
topics
# Out:
# Nutrition, Physical Activity, and Weight Status    37
# Cancer                                             20
# Diabetes                                           20
# Cardiovascular Disease                             18
# Overarching Conditions                             16
# Alcohol                                            16
# Chronic Obstructive Pulmonary Disease              16
# Tobacco                                            16
# Arthritis                                          10
# Oral Health                                         9
# Asthma                                              9
# Chronic Kidney Disease                              4
# Older Adults                                        4
# Mental Health                                       3
# Reproductive Health                                 3
# Immunization                                        1
# Disability                                          1
# Name: Topic, dtype: int64

# %% [markdown]
# # Filter out categories with few entries

# %%
df = df[df["Topic"].str.match("|".join(topics.nlargest(11).index.to_list()))].reset_index(drop=True)
df.head()
# Out:
#                                              Topic  \
# 0                                          Alcohol
# 1                                          Alcohol
# 2                                          Alcohol
# 3  Nutrition, Physical Activity, and Weight Status
# 4                           Cardiovascular Disease
#
#                                             Question
# 0  Amount of alcohol excise tax by beverage type ...
# 1  Amount of alcohol excise tax by beverage type ...
# 2  Amount of alcohol excise tax by beverage type ...
# 3              Obesity among adults aged >= 18 years
# 4  Hospitalization for heart failure among Medica...

# %%
tfidf = TfidfVectorizer()
csr_matrix  = tfidf.fit_transform(df["Question"])
csr_matrix.shape
# Out:
# (187, 383)

# %%
coords = TruncatedSVD(n_components=2).fit_transform(csr_matrix)
fig = plt.figure(figsize=(20, 10))
fig.suptitle("Embeddings of Questions by Topic", fontsize=28)
sns.scatterplot(coords[:,0], coords[:,1], hue=df["Topic"], s=50, cmap=plt.cm.Spectral)

# %%
coords = TSNE(n_components=2).fit_transform(csr_matrix.todense())
fig = plt.figure(figsize=(20, 10))
fig.suptitle("Embeddings of Questions by Topic", fontsize=28)
sns.scatterplot(coords[:,0], coords[:,1], hue=df["Topic"], s=50, cmap=plt.cm.Spectral)

# %%
tfidf.get_feature_names()
# Out:
# ['000',
#  '100',
#  '14',
#  '17',
#  '18',
#  '21',
#  '24',
#  '44',
#  '45',
#  '50',
#  '64',
#  '65',
#  '74',
#  '75',
#  'accept',
#  'activity',
#  'acute',
#  'additional',
#  'adolescents',
#  'adult',
#  'adults',
#  'aerobic',
#  'age',
#  'aged',
#  'alcohol',
#  'all',
#  'allow',
#  'among',
#  'amount',
#  'amputation',
#  'and',
#  'any',
#  'are',
#  'areas',
#  'arthritis',
#  'as',
#  'assistance',
#  'asthma',
#  'at',
#  'attempts',
#  'attributable',
#  'authority',
#  'avoiding',
#  'awareness',
#  'baby',
#  'bars',
#  'beer',
#  'before',
#  'benefits',
#  'beverage',
#  'binge',
#  'birth',
#  'births',
#  'blood',
#  'boundary',
#  'breast',
#  'breastfed',
#  'breastfeeding',
#  'bronchus',
#  'by',
#  'cancer',
#  'capita',
#  'cardiovascular',
#  'care',
#  'cause',
#  'cavity',
#  'cdc',
#  'census',
#  'centers',
#  'cerebrovascular',
#  'cervix',
#  'child',
#  'children',
#  'cholesterol',
#  'chronic',
#  'cigarette',
#  'class',
#  'classes',
#  'clinic',
#  'colon',
#  'colonoscopy',
#  'colorectal',
#  'combined',
#  'commercial',
#  'community',
#  'competitive',
#  'completion',
#  'comprehensive',
#  'computer',
#  'consumption',
#  'contributing',
#  'control',
#  'coronary',
#  'coupons',
#  'course',
#  'coverage',
#  'current',
#  'daily',
#  'days',
#  'death',
#  'density',
#  'dental',
#  'dentist',
#  'department',
#  'depressive',
#  'diabetes',
#  'diabetic',
#  'diagnosed',
#  'diagnosis',
#  'dilated',
#  'disease',
#  'diseases',
#  'disorders',
#  'distilled',
#  'doctor',
#  'dram',
#  'drink',
#  'drinking',
#  'drinks',
#  'due',
#  'early',
#  'education',
#  'eligible',
#  'emergency',
#  'examination',
#  'excise',
#  'expectancy',
#  'extensive',
#  'extremity',
#  'eye',
#  'facilities',
#  'failure',
#  'fair',
#  'farmers',
#  'fecal',
#  'federally',
#  'female',
#  'first',
#  'fluoridated',
#  'food',
#  'foods',
#  'foot',
#  'for',
#  'formula',
#  'free',
#  'frequency',
#  'friendly',
#  'from',
#  'fruit',
#  'fund',
#  'gestational',
#  'gini',
#  'glycosylated',
#  'guidelines',
#  'have',
#  'health',
#  'healthier',
#  'healthy',
#  'heart',
#  'heavy',
#  'hemoglobin',
#  'high',
#  'history',
#  'hospitalization',
#  'hospitalizations',
#  'host',
#  'hours',
#  'how',
#  'hypertension',
#  'in',
#  'inactivity',
#  'incidence',
#  'including',
#  'income',
#  'index',
#  'indoor',
#  'inequality',
#  'infant',
#  'infants',
#  'infarction',
#  'influenza',
#  'insurance',
#  'intensity',
#  'invasive',
#  'joint',
#  'ketoacidosis',
#  'lack',
#  'laws',
#  'learn',
#  'leisure',
#  'less',
#  'level',
#  'liability',
#  'licenses',
#  'life',
#  'limitation',
#  'listed',
#  'live',
#  'liver',
#  'local',
#  'loss',
#  'lost',
#  'lower',
#  'lung',
#  'mammography',
#  'manage',
#  'management',
#  'market',
#  'markets',
#  'maternity',
#  'mean',
#  'measurement',
#  'median',
#  'medicare',
#  'medicine',
#  'meeting',
#  'melanoma',
#  'mile',
#  'months',
#  'more',
#  'mortality',
#  'mpinc',
#  'muscle',
#  'myocardial',
#  'no',
#  'noninstitutionalized',
#  'normal',
#  'number',
#  'nutrition',
#  'obese',
#  'obesity',
#  'obstructive',
#  'occult',
#  'occurring',
#  'of',
#  'offer',
#  'onsite',
#  'optimally',
#  'or',
#  'oral',
#  'outlet',
#  'outside',
#  'overweight',
#  'packs',
#  'pain',
#  'papanicolaou',
#  'participation',
#  'past',
#  'per',
#  'percent',
#  'persons',
#  'pertaining',
#  'pharynx',
#  'physical',
#  'physically',
#  'place',
#  'places',
#  'pneumococcal',
#  'polices',
#  'policy',
#  'poor',
#  'population',
#  'poverty',
#  'practices',
#  'pre',
#  'pregnancy',
#  'premature',
#  'presence',
#  'pressure',
#  'prevalence',
#  'prevention',
#  'preventive',
#  'product',
#  'products',
#  'program',
#  'prohibiting',
#  'proportion',
#  'prostate',
#  'protected',
#  'public',
#  'pulmonary',
#  'purchase',
#  'qualified',
#  'quit',
#  'rate',
#  'rated',
#  'receive',
#  'receiving',
#  'recent',
#  'recommended',
#  'rectum',
#  'regulate',
#  'regulation',
#  'regulations',
#  'reported',
#  'require',
#  'residents',
#  'restaurants',
#  'retail',
#  'retailers',
#  'revenue',
#  'sale',
#  'school',
#  'schools',
#  'score',
#  'screen',
#  'screening',
#  'secondary',
#  'self',
#  'sell',
#  'served',
#  'services',
#  'serving',
#  'settings',
#  'severe',
#  'shop',
#  'sigmoidoscopy',
#  'sites',
#  'six',
#  'sleep',
#  'smear',
#  'smoke',
#  'smokeless',
#  'smokers',
#  'smoking',
#  'snap',
#  'soda',
#  'spirits',
#  'sponsored',
#  'sports',
#  'state',
#  'states',
#  'status',
#  'strengthening',
#  'stroke',
#  'strong',
#  'stronger',
#  'students',
#  'substantial',
#  'sufficient',
#  'sugar',
#  'supplemental',
#  'supplementation',
#  'supports',
#  'symptoms',
#  'systems',
#  'taken',
#  'taking',
#  'tax',
#  'teeth',
#  'television',
#  'test',
#  'that',
#  'the',
#  'time',
#  'to',
#  'tobacco',
#  'tooth',
#  'total',
#  'tracts',
#  'type',
#  'underlying',
#  'unhealthy',
#  'use',
#  'vaccination',
#  'vegetable',
#  'vegetables',
#  'viewing',
#  'visit',
#  'visits',
#  'water',
#  'weight',
#  'who',
#  'wic',
#  'wine',
#  'with',
#  'within',
#  'women',
#  'work',
#  'workplaces',
#  'year',
#  'years',
#  'youth']

# %%
tfidf.get_params()
# Out:
# {'analyzer': 'word',
#  'binary': False,
#  'decode_error': 'strict',
#  'dtype': numpy.float64,
#  'encoding': 'utf-8',
#  'input': 'content',
#  'lowercase': True,
#  'max_df': 1.0,
#  'max_features': None,
#  'min_df': 1,
#  'ngram_range': (1, 1),
#  'norm': 'l2',
#  'preprocessor': None,
#  'smooth_idf': True,
#  'stop_words': None,
#  'strip_accents': None,
#  'sublinear_tf': False,
#  'token_pattern': '(?u)\\b\\w\\w+\\b',
#  'tokenizer': None,
#  'use_idf': True,
#  'vocabulary': None}

# %%
tfidf.idf_
# Out:
# array([5.54329478, 5.54329478, 5.54329478, 5.13782967, 2.00233546,
#        5.13782967, 5.54329478, 3.67149261, 4.03921739, 5.13782967,
#        3.75153531, 3.52839176, 5.54329478, 5.54329478, 5.13782967,
#        3.83854669, 5.54329478, 5.54329478, 5.13782967, 5.54329478,
#        1.90570862, 4.62700405, 5.54329478, 1.73663229, 4.15700042,
#        4.62700405, 4.62700405, 1.5359616 , 4.62700405, 5.54329478,
#        3.40322862, 4.44468249, 5.54329478, 5.54329478, 3.83854669,
#        3.67149261, 5.54329478, 3.93385687, 4.29053181, 5.54329478,
#        5.54329478, 5.54329478, 5.54329478, 5.13782967, 5.54329478,
#        5.54329478, 5.54329478, 4.62700405, 4.62700405, 4.8501476 ,
#        4.44468249, 5.54329478, 5.54329478, 4.44468249, 5.54329478,
#        5.13782967, 5.13782967, 5.54329478, 5.13782967, 4.29053181,
#        3.52839176, 5.54329478, 5.54329478, 4.03921739, 4.62700405,
#        5.13782967, 5.54329478, 5.54329478, 5.54329478, 5.54329478,
#        5.13782967, 5.54329478, 4.8501476 , 4.8501476 , 3.3460702 ,
#        4.62700405, 5.54329478, 5.54329478, 5.13782967, 5.13782967,
#        5.54329478, 5.13782967, 5.13782967, 5.54329478, 5.13782967,
#        5.54329478, 5.13782967, 5.13782967, 5.54329478, 4.29053181,
#        5.54329478, 5.13782967, 4.44468249, 5.54329478, 5.54329478,
#        5.13782967, 3.75153531, 4.44468249, 5.13782967, 5.13782967,
#        5.54329478, 4.44468249, 5.13782967, 4.8501476 , 5.54329478,
#        3.19191953, 5.54329478, 3.19191953, 4.15700042, 5.54329478,
#        3.01756614, 5.13782967, 5.54329478, 5.54329478, 4.8501476 ,
#        5.54329478, 5.13782967, 4.03921739, 5.13782967, 4.62700405,
#        4.62700405, 4.44468249, 4.8501476 , 4.8501476 , 5.13782967,
#        4.62700405, 5.13782967, 5.54329478, 5.54329478, 5.54329478,
#        5.13782967, 5.13782967, 5.13782967, 4.8501476 , 5.54329478,
#        5.54329478, 4.8501476 , 4.62700405, 5.54329478, 5.54329478,
#        5.54329478, 5.54329478, 3.46385324, 5.54329478, 5.13782967,
#        4.44468249, 5.54329478, 4.44468249, 4.62700405, 5.54329478,
#        5.54329478, 5.54329478, 5.54329478, 4.62700405, 4.03921739,
#        3.83854669, 5.54329478, 4.8501476 , 3.93385687, 5.13782967,
#        5.54329478, 3.29200298, 4.62700405, 4.03921739, 5.54329478,
#        5.54329478, 5.54329478, 5.54329478, 5.54329478, 3.93385687,
#        5.54329478, 4.03921739, 5.54329478, 5.54329478, 5.54329478,
#        5.54329478, 5.54329478, 5.13782967, 5.13782967, 5.54329478,
#        4.15700042, 5.13782967, 5.54329478, 4.15700042, 5.54329478,
#        5.54329478, 5.54329478, 5.13782967, 5.54329478, 5.54329478,
#        5.54329478, 5.54329478, 5.54329478, 5.54329478, 4.8501476 ,
#        4.44468249, 4.29053181, 5.54329478, 5.54329478, 5.13782967,
#        5.54329478, 5.13782967, 5.54329478, 5.13782967, 5.54329478,
#        5.54329478, 5.54329478, 5.54329478, 4.8501476 , 5.54329478,
#        5.54329478, 5.54329478, 4.62700405, 4.8501476 , 5.54329478,
#        4.62700405, 5.13782967, 5.54329478, 5.54329478, 5.13782967,
#        3.19191953, 5.54329478, 5.54329478, 5.54329478, 5.13782967,
#        3.40322862, 5.54329478, 5.54329478, 4.8501476 , 5.54329478,
#        4.44468249, 3.40322862, 5.54329478, 5.54329478, 2.21109027,
#        5.54329478, 5.54329478, 5.54329478, 3.52839176, 4.8501476 ,
#        5.54329478, 5.54329478, 4.8501476 , 5.54329478, 5.54329478,
#        5.13782967, 5.54329478, 5.54329478, 5.13782967, 5.54329478,
#        4.62700405, 4.62700405, 5.13782967, 4.03921739, 5.54329478,
#        5.54329478, 5.54329478, 3.93385687, 5.54329478, 5.13782967,
#        5.13782967, 5.13782967, 5.13782967, 5.54329478, 5.13782967,
#        4.29053181, 5.54329478, 4.62700405, 4.62700405, 3.19191953,
#        5.54329478, 5.13782967, 5.54329478, 5.54329478, 5.13782967,
#        5.54329478, 5.54329478, 5.13782967, 5.54329478, 5.54329478,
#        3.40322862, 5.13782967, 5.54329478, 5.54329478, 4.62700405,
#        5.13782967, 5.54329478, 5.54329478, 4.8501476 , 5.54329478,
#        5.13782967, 5.54329478, 5.54329478, 4.62700405, 5.13782967,
#        5.54329478, 5.54329478, 5.54329478, 5.54329478, 5.54329478,
#        5.54329478, 5.54329478, 3.52839176, 4.44468249, 5.54329478,
#        5.54329478, 5.54329478, 4.44468249, 4.8501476 , 5.54329478,
#        5.54329478, 5.54329478, 5.13782967, 4.62700405, 5.54329478,
#        5.54329478, 5.54329478, 5.13782967, 5.54329478, 5.54329478,
#        5.13782967, 4.8501476 , 5.13782967, 5.54329478, 4.15700042,
#        5.54329478, 5.13782967, 5.54329478, 5.54329478, 5.54329478,
#        5.54329478, 5.13782967, 5.13782967, 5.54329478, 4.62700405,
#        5.54329478, 5.54329478, 3.67149261, 5.13782967, 5.54329478,
#        5.54329478, 5.54329478, 5.54329478, 5.54329478, 5.54329478,
#        5.54329478, 5.13782967, 5.54329478, 4.62700405, 5.13782967,
#        5.54329478, 5.54329478, 3.83854669, 3.40322862, 5.13782967,
#        3.3460702 , 4.15700042, 5.54329478, 5.54329478, 5.54329478,
#        4.8501476 , 5.13782967, 5.54329478, 3.93385687, 3.40322862,
#        5.13782967, 5.54329478, 5.54329478, 4.8501476 , 4.62700405,
#        5.54329478, 5.13782967, 3.67149261, 5.54329478, 5.54329478,
#        2.62552405, 5.13782967, 3.46385324, 5.54329478, 5.54329478,
#        5.54329478, 1.69314718, 4.44468249])

# %%
def extract_keywords(idx):
    feature_names = tfidf.get_feature_names()
    feature_index = csr_matrix[idx,:].nonzero()[1]
    tfidf_scores = zip(feature_index, [csr_matrix[idx, x] for x in feature_index])
    return [(feature_names[i], s) for (i, s) in tfidf_scores]

# %%
df[df["Topic"] == "Alcohol"].index.to_list()
# Out:
# [0, 1, 2, 5, 9, 11, 18, 21, 56, 57, 61, 65, 99, 114, 166, 178]

# %%
feature_names = tf.get_feature_names()
doc = 0
feature_index = X[doc,:].nonzero()[1]
tfidf_scores = zip(feature_index, [X[doc, x] for x in feature_index])
for w, s in [(feature_names[i], s) for (i, s) in tfidf_scores]:
    print w, s
